# %%
import codecs, bs4


file = codecs.open('106.html', 'r','utf-8')  #読み込みモードでオープン
string = file.read()      #readですべて読み込む
#print(code)
soup = bs4.BeautifulSoup(string, "html.parser")
elems = soup.select('p')
elemc = soup.find_all("p", class_="novel")
for elem in elemc:
    #print(elem)
    stre =  str(elem)

    # エンコーディング判別
    #guess = chardet.detect(stre)
    # Unicode化
    #unicode_data = stre.decode(guess['encoding'])
    print(elem.getText())
    #print(stre)

   # print(elem.getText())
   # print ('roopFIN')
# Out:
# 今日は『あれ』に会いに行く日。
#
#
# 大がかりな荷物を引き歩く私に「お疲れ様です」と挨拶する駅の皆。どこに行くかは、ここの皆はわかっているからね。
# 京成成田駅の改札を出て歩くこと数十分。こぢんまりとしたアパートの一部屋の前で立ち止まって、インターホンを押す。
# 「上野です。起きてるなら、開けて」
# 呼びかけると慌ただしく足音が響いて、ドアが開いた。出汁の匂いが鼻を撫で、口内を湿らせる。
# 『あれ』はドアから半身を乗り出し様子を伺う。その中学生のような体型と黒くよどんだ目つきはこの前と何ら変わりなく、良くも悪くも私を安心させる。
# 「飯なら用意してある」
# そう言って『あれ』はドアを開き、キッチンに戻った。私も荷物を廊下に置き、キッチンに向かう。そこにはジャージ姿でうどんを茹でる『あれ』の姿があった。背伸びをして棚を開ける様子を見たら、中学生としか思えない。
# 「冷凍ご飯持ってきたけど、この調子なら要らないね」
# 「米くらい炊ける」
# なんでこうも無愛想な言い方しか出来ないんだろうとため息をつく。昔からこうだから、直そうとも思えないけれど。
# 「出来た。あっちで待っててくれ」
# もう少し様子を見ようと思っていたら追い出されてしまった。
#
#
# 居間に入ると、書類と鞄と、色々が混ざって散乱している様が目に映る。これには、どうしても顔をしかめてしまう。だけどもカップ麵の残り汁がおいていないだけいいとしよう。
# ちゃぶ台の横に座り込むと、ホコリが喉に付き、咳き込んでしまった。薄暗いうえに、埃臭い。これではこちらも病んでしまいそうだ。
# ひとまず濡れたティッシュでちゃぶ台を拭く。拭き終わると『あれ』がうどんをお盆に乗せ部屋に入ってきた。
#
# 「手前が上野の分。唐辛子は要る？　」
# 「いらない」
# お椀をこちらに運び、覗く。うどんとつゆ以外に何もない、所謂素うどんだ。
# 具もないうどんを凝視する私を不審に思ったのか、『あれ』が声を掛ける。
# 「おれにしては頑張ったんだ」
# 顔を上げると、『あれ』は大層不満げに顔をしかめていた。勝手に責められたと思い込むのはやめて欲しい。
# 私は小さく息を吐き、うどんをすすった。
# ごく普通。良いとは言えないけど、口直しが必要なものでもない。
# 「不味いか」
# 不安そうに『あれ』が私に問うので、答えてあげることにする。
# 「東成田にしては、頑張った方じゃないかな」
# 「食える味ってことか」
# 「まあ、そうだね」
#
#
# お腹にモノもため込んだところで、私は鞄から書類を取り出す。
# それを見た『あれ』の顔はみるみるうちに真っ青に、そして瞳も普段に増して黒ずんでしまった。
# 「あ……それ、は」
# 人差し指で示した先には私が手に取った資料。
# 「見たくない？　」
# その眼には泪が滲んでいる。手足がガタガタと小刻みに振動し、余程の恐怖なんだと容易に分かってしまう。
# 「や、やめてくれ……おれには、もう、嫌だ」
# 「これを見てもらうまでは帰れないから、つべこべ言わずに見てよ」
# だけど、これも仕事。私はちゃぶ台に数字の並ぶ書類を置き、『あれ』を諌める。
# 「こんなの、見たくない。帰ってくれ」
# 「いつまでそうしてるつもりなの、東成田」
# 頭を抱えて私から、資料から目を背けている。
# 「帰ってくれよ」
# 「ほら、向き合いなよ。現実と」
# 私は恐怖に打ち震える『あれ』をよそに資料を読み上げる。
# 「二千○○年度駅別乗降人員」
# 『あれ』は耳を塞ぎ、浅い呼吸を繰り返すのみ。
# 「東成田線、○○人。前年度より○○人減少。東成田駅の利用者数……」
# 人数を伝えた途端に『あれ』が喚きだす。私は意にも介さず一回り声を大きくして、続ける。
#
# 減少、と伝えた途端。『あれ』の呼吸が止まった。と思うと汚い呻き声が部屋じゅうに染み渡る。
#
# 「また、減っちゃったね」
# 減少したことを強調し、地に落とす勢いで小突く。
#
# 「ごめんなさい、ごめんなさい。おれが、おれが悪いんです、だからもう言わないでください」
# 丸まってふさぎ込み早口で赦しを請う『あれ』の姿は醜く、惨たらしい。
# だけど何故か、得体の知れない悦楽を私にもたらすんだ。
# 「悪いと思ってるんだったら、どうしたらいいか。わかるよね」
# 「がんばります、足引っ張らないように、がんばります」
# はきはきと詞を放つ『あれ』。もう、自分でも何が何だかわかっていないんだと思う。
#
# 私はとびっきりの笑顔で、激励の言葉を告げる。
#
# 「今年こそは、増えるように頑張ってね」
#
# 残りの資料も『あれ』の元に置き、私は悠々と帰宅の準備を進めた。

# %%
import codecs, bs4

name = input("ファイル名を入力[拡張子は除く]: ")
filename = name + '.html'
file = codecs.open(filename, 'r','utf-8')  #読み込みモードでオープン
string = file.read()      #readですべて読み込む
file.close()
#print(code)
soup = bs4.BeautifulSoup(string, "html.parser")
elems = soup.select('p')
elemc = soup.find_all("p", class_="novel")

wr = open(name+'.txt', 'w')  #書き込みモードでオープン
string55 = 'python output string'

 
wr.write(string55)
wr.close()
for elem in elemc:
    #print(elem)
    stre =  str(elem)

    # エンコーディング判別
    #guess = chardet.detect(stre)
    # Unicode化
    #unicode_data = stre.decode(guess['encoding'])
    print(elem.getText())
    #print(stre)

   # print(elem.getText())
   # print ('roopFIN')
# Out:
# ファイル名を入力[拡張子は除く]: 106
#
#
# 今日は『あれ』に会いに行く日。
#
#
# 大がかりな荷物を引き歩く私に「お疲れ様です」と挨拶する駅の皆。どこに行くかは、ここの皆はわかっているからね。
# 京成成田駅の改札を出て歩くこと数十分。こぢんまりとしたアパートの一部屋の前で立ち止まって、インターホンを押す。
# 「上野です。起きてるなら、開けて」
# 呼びかけると慌ただしく足音が響いて、ドアが開いた。出汁の匂いが鼻を撫で、口内を湿らせる。
# 『あれ』はドアから半身を乗り出し様子を伺う。その中学生のような体型と黒くよどんだ目つきはこの前と何ら変わりなく、良くも悪くも私を安心させる。
# 「飯なら用意してある」
# そう言って『あれ』はドアを開き、キッチンに戻った。私も荷物を廊下に置き、キッチンに向かう。そこにはジャージ姿でうどんを茹でる『あれ』の姿があった。背伸びをして棚を開ける様子を見たら、中学生としか思えない。
# 「冷凍ご飯持ってきたけど、この調子なら要らないね」
# 「米くらい炊ける」
# なんでこうも無愛想な言い方しか出来ないんだろうとため息をつく。昔からこうだから、直そうとも思えないけれど。
# 「出来た。あっちで待っててくれ」
# もう少し様子を見ようと思っていたら追い出されてしまった。
#
#
# 居間に入ると、書類と鞄と、色々が混ざって散乱している様が目に映る。これには、どうしても顔をしかめてしまう。だけどもカップ麵の残り汁がおいていないだけいいとしよう。
# ちゃぶ台の横に座り込むと、ホコリが喉に付き、咳き込んでしまった。薄暗いうえに、埃臭い。これではこちらも病んでしまいそうだ。
# ひとまず濡れたティッシュでちゃぶ台を拭く。拭き終わると『あれ』がうどんをお盆に乗せ部屋に入ってきた。
#
# 「手前が上野の分。唐辛子は要る？　」
# 「いらない」
# お椀をこちらに運び、覗く。うどんとつゆ以外に何もない、所謂素うどんだ。
# 具もないうどんを凝視する私を不審に思ったのか、『あれ』が声を掛ける。
# 「おれにしては頑張ったんだ」
# 顔を上げると、『あれ』は大層不満げに顔をしかめていた。勝手に責められたと思い込むのはやめて欲しい。
# 私は小さく息を吐き、うどんをすすった。
# ごく普通。良いとは言えないけど、口直しが必要なものでもない。
# 「不味いか」
# 不安そうに『あれ』が私に問うので、答えてあげることにする。
# 「東成田にしては、頑張った方じゃないかな」
# 「食える味ってことか」
# 「まあ、そうだね」
#
#
# お腹にモノもため込んだところで、私は鞄から書類を取り出す。
# それを見た『あれ』の顔はみるみるうちに真っ青に、そして瞳も普段に増して黒ずんでしまった。
# 「あ……それ、は」
# 人差し指で示した先には私が手に取った資料。
# 「見たくない？　」
# その眼には泪が滲んでいる。手足がガタガタと小刻みに振動し、余程の恐怖なんだと容易に分かってしまう。
# 「や、やめてくれ……おれには、もう、嫌だ」
# 「これを見てもらうまでは帰れないから、つべこべ言わずに見てよ」
# だけど、これも仕事。私はちゃぶ台に数字の並ぶ書類を置き、『あれ』を諌める。
# 「こんなの、見たくない。帰ってくれ」
# 「いつまでそうしてるつもりなの、東成田」
# 頭を抱えて私から、資料から目を背けている。
# 「帰ってくれよ」
# 「ほら、向き合いなよ。現実と」
# 私は恐怖に打ち震える『あれ』をよそに資料を読み上げる。
# 「二千○○年度駅別乗降人員」
# 『あれ』は耳を塞ぎ、浅い呼吸を繰り返すのみ。
# 「東成田線、○○人。前年度より○○人減少。東成田駅の利用者数……」
# 人数を伝えた途端に『あれ』が喚きだす。私は意にも介さず一回り声を大きくして、続ける。
#
# 減少、と伝えた途端。『あれ』の呼吸が止まった。と思うと汚い呻き声が部屋じゅうに染み渡る。
#
# 「また、減っちゃったね」
# 減少したことを強調し、地に落とす勢いで小突く。
#
# 「ごめんなさい、ごめんなさい。おれが、おれが悪いんです、だからもう言わないでください」
# 丸まってふさぎ込み早口で赦しを請う『あれ』の姿は醜く、惨たらしい。
# だけど何故か、得体の知れない悦楽を私にもたらすんだ。
# 「悪いと思ってるんだったら、どうしたらいいか。わかるよね」
# 「がんばります、足引っ張らないように、がんばります」
# はきはきと詞を放つ『あれ』。もう、自分でも何が何だかわかっていないんだと思う。
#
# 私はとびっきりの笑顔で、激励の言葉を告げる。
#
# 「今年こそは、増えるように頑張ってね」
#
# 残りの資料も『あれ』の元に置き、私は悠々と帰宅の準備を進めた。

# %%
import codecs, bs4

name = input("ファイル名を入力[拡張子は除く]: ")
filename = 'novel/'+name + '.html'
file = codecs.open(filename, 'r','utf-8')  #読み込みモードでオープン
string = file.read()      #readですべて読み込む
file.close()
#print(code)
soup = bs4.BeautifulSoup(string, "html.parser")
elems = soup.select('p')
elemc = soup.find_all("p", class_="novel")

wr = open(name+'.txt', 'w')  #書き込みモードでオープン
string55 = 'python output string'

 
wr.write(string55)
wr.close()
for elem in elemc:
    #print(elem)
    stre =  str(elem)

    # エンコーディング判別
    #guess = chardet.detect(stre)
    # Unicode化
    #unicode_data = stre.decode(guess['encoding'])
    print(elem.getText())
    #print(stre)

   # print(elem.getText())
   # print ('roopFIN')
# Out:
# ファイル名を入力[拡張子は除く]: 117
#
# 「五日市さん大丈夫ですかね、自分で言っておいてなんですが」
# 手汗が滲むジョッキを片手にビールを飲み干すと、八高に問いかける。しかし返事がない。
# まさかビール１杯で潰れたのかと戸惑う鶴見は彼の背中をゆすった。
# しばし肩を叩いているとその手に気味の悪い感覚が忍び寄る。
# 酔いを覚まそうと水を一口飲み彼の項を見ると、頭髪が伸びていた。それはとてもこの数秒で伸びたとは思えない程に。
# 「八高さんって後ろは長かったんすね」
# 酩酊しきった頭ではそれが何を示しているのか、彼には分からなかった。
#
#
# 起きそうにない八高を横目に鶴見は会計の準備を始めようと伝票を取り寄せていた。
# 伝票の数字に吃驚してため息をつくと、その背にふと暖かいものを感じとる。
# 「なーんだ、まだ会計取ってなかったのか。もう一時間やろうぜ」
# ニヤニヤと笑う八高に、驚きと気味の悪さで怖気づき伝票を床に落としてしまう。
# 年末大特番を見ていたときでさえ決して見せたことのない笑顔に背筋が凍る。
# 「あ、脳震盪でも起こしたのかな。ええと、こういうときは……」
# 酔いが回った覚束ない指先で携帯電話を動かしていると、人を小馬鹿にしたような薄笑いを浮かべた八高がそれを上からつまみとってしまった。
# 「勝手に病院行きにすんなよな」
# 八高は馴染みのない数字の羅列を見ると画面を消灯し、自分の内ポケットにしまいこんだ。
# 「だ、だって俺の知ってる八高さんは」
# 「どうしようもなくバカでおまけに無愛想、間違ってもこんな笑い方はしないって言いたいんだろ？」
# 自虐としか思えないその軽々とした口ぶりに、返事に困った鶴見は口を噤んでしまう。
# 「そもそも口調が変わりすぎたか、驚かせてごめんな。十数年ぶりの再会に心躍っちまってさ！」
# 一呼吸置き、彼の顔を凝視する。八高は変わらず皮肉な笑みを浮かべている。すると得体の知れない悪寒で身体は竦み上がってしまった。鶴見は汗でベタベタになった手で伝票を拾い上げすぐさま伝票を拾い上げ店員に手渡した。
# その顔は先程とは打って変わってガチガチに固まり、青ざめている。
# 「また十年後に会いましょう」
# お釣りはいりませんと口にし店員へ5枚の札を渡すと鶴見はそそくさと店から去ってしまった。
#
#
# 彼を追うこともなく残った焼酎を飲み干すと、八高は嗤いだした。
# 「あーあ、今日も一人か」
# そんな彼を見ていたたまれなくなったのか、カウンターにいた店員が声をかける。
# 「お辛いでしょう」
# なんてことのないありふれた台詞。聞き飽きたその言葉に彼の瞳から光が消える。
# 視線は空になったお猪口へと向けられ、口を開くこともなく最後の一滴を注ぎ込もうと軽くなった四合瓶を逆さにする。
# 「いーや、これはいつものこと。僕のことは気にせず、他の人の注文でも取りに行ってください」
# しかし何度振っても瓶からは何も出ることはなく、どこか居心地の悪さに苛立った八高は荷物を持ち椅子から降りる。
# 「どうも、ご馳走様でした」
# 店員は終始口元を崩さず語る男に疑問を覚えつつも、いつものように軽い会釈と挨拶をした。
#
#
# 息も凍る真冬の夜に、彼はジャケットを小脇に抱えて駅へと歩いていた。
# 赤信号に捕まって、ふと胸に違和感を覚える。
# 内ポケットには蒼白のまま帰っていった鶴見の携帯電話があった。
# 記憶を巡らせるまでもない、これはいけない。
# 「しまった」
# 焼けるような焦燥が彼を襲い、顔は青ざめる。八高は信号の色も見ず一目散に駅へと駆け込んだ。
#
# 改札をくぐったとき、列車の発つ音が駅舎に響き渡った。
# 間に合わなかったのだ。
#
# はぁ、とため息を漏らし八高は青梅線の終電に乗り遅れぬようホームへと向かった。
#
#
#
# --------------------
#
#
#
#
#
#
# 昔からそうだ。
# "僕"は皆が好きなのに、皆は"僕"を嫌う。
# 携帯電話は"君"に届けてもらうしかないか。
#
# 吊革に手を掛け明日の予定を潜考していると、店員の言葉が反芻して脳をかき乱していった。
# まただ、と思考を跳ね除けた"八高"だったが、今回のそれは執拗に彼をつけまわしている。
# そして感情の伴わない思考は彼の五感を奪い取り、かつての光景を見せつけた。
# 「ああ、あの時の」
# そしてそれが顕にしたものは、とうに消えたはずだった"一歩先に踏み出せない己への慚愧の念"。
# しかし、"八高"にそれは響かなかった。少なくとも彼自身は、そう感じていた。
#
# 「慣れっこだって、さっきから言ってるじゃないか。僕に更生を望んでも徒労に終わるって分かってんだろ、"南くん"」
#
# 吊革に力を込め思考をかき消すと、強烈な眠気が彼を襲う。耐えきれずに足はよろけ、隣にいた酔客に肩をぶつけてしまった。
# 「すみません」
# なんとか絞り出した謝罪の言葉に、酔客はわざとらしく舌打ちで応える。しかしそれに苛立つ気力も体力も八高には残っておらず、目的の駅につくと駅員たちの挨拶も無視して宿舎へと向かっていった。
#
#
# 宿舎の個室のドアを開けると、八高はスーツを脱ぎ風呂に入ることさえせず布団に飛び込んだ。
# 「あー疲れた。どうして"南くん"は僕に情を植え付けようと躍起になってんだ」
# 分厚い掛け布団にくるまり、その端を握り潰す。
# 「しばらく僕はおやすみするよ。またね」
# 壁に向かって語られたその詞は、彼が眠りについてもなお部屋に響き渡っていた。
